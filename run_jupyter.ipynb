# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from main import GMM_EM
from main import data_creation
data = data_creation()

# %%
means = 3
solution = GMM_EM(means, data)

# %%
for i in range(100):
    solution.E_step()
    solution.M_step()

# %%
plt.scatter(solution.data[:, 0], solution.data[:, 1], s=40, cmap='viridis');
for i in range(means):
    plt.scatter(solution.functions[i].means[0], solution.functions[i].means[1], s=100)
